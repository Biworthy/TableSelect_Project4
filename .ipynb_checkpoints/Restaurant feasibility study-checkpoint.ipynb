# %%
import pandas as pd
import json
import csv
import os
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import OrdinalEncoder,MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.models import load_model

# %%
import sys

# !$sys.executable -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp39-cp39-macosx_10_14_x86_64.whl (228.5 MB)
#      |████████████████████████████████| 228.5 MB 11 kB/s s eta 0:00:01  |▍                               | 2.7 MB 1.7 MB/s eta 0:02:10     |█████▎                          | 37.6 MB 11.9 MB/s eta 0:00:17     |█████████▏                      | 65.8 MB 34.7 MB/s eta 0:00:05
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.46.1)
# Requirement already satisfied: numpy>=1.20 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.20.3)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: libclang>=13.0.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.9.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.2.1)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.0)
# Requirement already satisfied: six>=1.12.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: setuptools in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/MadhuSlokaPj/opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Installing collected packages: keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-pasta-0.2.0 keras-2.9.0 tensorflow-2.9.1

# %%
# Out:
#   File "/var/folders/j6/3b4wlhj95714xv9_qvx9fqyc0000gn/T/ipykernel_80034/2629281692.py", line 1
#     file -I 'business2_csv.csv'
#             ^
# SyntaxError: invalid syntax

# %%
#yelp_business_df = pd.read_json('yelp_academic_dataset_business.json',lines=True)
#yelp_checkin_df = pd.read_json('yelp_academic_dataset_checkin.json',lines=True)
#yelp_review_df = pd.read_json('yelp_academic_dataset_review.json',lines=True,chunksize=100000)
#yelp_tip_df = pd.read_json('yelp_academic_dataset_tip.json',lines=True)
#yelp_user_df = pd.read_json('yelp_academic_dataset_user.json',lines=True,chunksize=100000)
restaurant_bus_df = pd.read_excel('business2_csv.xls')
income_data = pd.read_csv('incomevalues.csv',thousands=',',encoding='cp1252')

# %%
restaurant_bus_df.head(10)
# Out:
#                                Name       Cuisine  Ratings  Reviews Price_Rng  \
# 0            Atlanta Breakfast Club      Southern      4.5     4900        $$
# 1        JINYA Ramen Bar - Buckhead         Ramen      4.5     1021        $$
# 2  Hattie B's Hot Chicken - Atlanta      Southern      4.5     1819        $$
# 3          Southern Kitchen & Grill      Southern      4.5      231        $$
# 4                     Poor Calvin's  Asian Fusion      4.5     3868       $$$
# 5                   Birria el Gordo         Tacos      4.5      174        $$
# 6        Mushi Ni at Little Trouble  Asian Fusion      5.0      247        $$
# 7                      Slutty Vegan         Vegan      4.5      945        $$
# 8                 Fox Bros. Bar-B-Q      Barbeque      4.5     4098        $$
# 9                     Ponko Chicken  Asian Fusion      4.5      287        $$
#
#   Zip-Code
# 0    30313
# 1    30342
# 2    30307
# 3    30340
# 4    30308
# 5    30060
# 6    30318
# 7    30310
# 8    30307
# 9    30309

# %% [raw]
# income_data.head(10)

# %%
restaurant_bus_df.drop(columns=['Unnamed: 0','ID','Latitude','Longitude'],inplace=True)
restaurant_bus_df=restaurant_bus_df.astype(dtype={'Zip-Code':str})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j6/3b4wlhj95714xv9_qvx9fqyc0000gn/T/ipykernel_80034/743986009.py in <module>
# ----> 1 restaurant_bus_df.drop(columns=['Unnamed: 0','ID','Latitude','Longitude'],inplace=True)
#       2 restaurant_bus_df=restaurant_bus_df.astype(dtype={'Zip-Code':str})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'ID' 'Latitude' 'Longitude'] not found in axis"

# %%
enc = OneHotEncoder()
restaurant_bus_df = pd.merge(left=restaurant_bus_df,right=pd.DataFrame(data=enc.fit_transform(restaurant_bus_df[['Price_Rng']]),columns=['Price_Rng_enc'],dtype=int),left_index=True,right_index=True).drop(columns=['Price_Rng'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'csr_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/j6/3b4wlhj95714xv9_qvx9fqyc0000gn/T/ipykernel_80034/4058094893.py in <module>
#       1 enc = OneHotEncoder()
# ----> 2 restaurant_bus_df = pd.merge(left=restaurant_bus_df,right=pd.DataFrame(data=enc.fit_transform(restaurant_bus_df[['Price_Rng']]),columns=['Price_Rng_enc'],dtype=int),left_index=True,right_index=True).drop(columns=['Price_Rng'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     311         rcf = not (is_integer_dtype(dtype) and values.dtype.kind == "f")
#     312
# --> 313         values = sanitize_array(
#     314             flat, None, dtype=dtype, copy=copy, raise_cast_failure=rcf
#     315         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     543         else:
#     544             # we will try to copy by-definition here
# --> 545             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     546
#     547     elif isinstance(data, ABCExtensionArray):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     752             # this will raise if we have e.g. floats
#     753
# --> 754             subarr = maybe_cast_to_integer_array(arr, dtype)
#     755         else:
#     756             # 4 tests fail if we move this to a try/except/else; see
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_integer_array(arr, dtype, copy)
#    2040             casted = np.array(arr, dtype=dtype, copy=copy)
#    2041         else:
# -> 2042             casted = arr.astype(dtype, copy=copy)
#    2043     except OverflowError as err:
#    2044         raise OverflowError(
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# Data Visualization

# %%
f,ax = plt.subplots(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=restaurant_bus_df,x='Zip-Code',order=restaurant_bus_df['Zip-Code'].value_counts().index,ax=ax)

# %% [markdown]
# The above bar chart shows the number of restaurants in a particular area (Zip-Code). This distribution clearly indicates that
# there is an uneven distribution of restaurants amongst different zipcodes. There are large number of restaurants in the
# zip-codes 30318,30309,30308,30303,30305. This distribution indicates that certain areas have high commercial activities.

# %%
f,ax = plt.subplots(figsize=(22,10))
plt.xticks(rotation=90)
sns.countplot(data=restaurant_bus_df,x='Cuisine',order=restaurant_bus_df['Cuisine'].value_counts().index,ax=ax)
# Out:
# <AxesSubplot:xlabel='Cuisine', ylabel='count'>

# %% [markdown]
# The bar chart indicates the distribution of the most liked cusines in the state of Georgia, US. Certain cusines are very much
# liked by the people. This indicates the taste of the common people.
# Georgia is the state in South of U.S.A and therefore "Southern" is liked by most of the people there. Other cusines are Burger,
# Pizza. People in this area are not wine lovers.

# %%
sns.set(style='darkgrid')
f,ax = plt.subplots(figsize=(15,22))
plt.xticks(rotation=90)
sns.scatterplot(data=restaurant_bus_df,x='Zip-Code',y='Cuisine',size='Price_Rng_enc',hue='Price_Rng_enc',palette=['red','blue','green','black'],sizes=[50,100,150,200],ax=ax)
# Out:
# <AxesSubplot:xlabel='Zip-Code', ylabel='Cuisine'>

# %% [markdown]
# The above scatter plot shows relation ship between three variables - "Cusine","Zip-Code" and "Price range". This plot clearly shows
# that most of the restaurants have less price range. The swarm of dots in above left quadrant shows that there are few cusines which
# are liked by the people and in certain areas.This is a clear indicator about well defined tatse of the people and the well defined
# commercial spots.
# This plot also indicates that food delivery services are most expensive and very few.

# %%
f,ax = plt.subplots(figsize=(15,10))
plt.xticks(rotation=90)
sns.scatterplot(data=restaurant_bus_df,x='Zip-Code',y='Reviews',hue='Price_Rng_enc',palette=['red','blue','green','black'],size='Ratings',sizes=[50,50,50,50,100,100,200,200,200],ax=ax)
# Out:
# <AxesSubplot:xlabel='Zip-Code', ylabel='Reviews'>

# %% [markdown]
# The above scatter plot shows relationship between 4 features - Number of Reveiws given to a restaurant,Zipcode,Price range and the
# average rating of a restaurant.The plot shows that most of the restaurants have less than 1000 reviews which indicates that most of
# the restaurants are new. The average rating of most of the restaurants is good.

# %%
f,ax = plt.subplots(figsize=(25,10))
plt.xticks(rotation=90)
sns.scatterplot(data=restaurant_bus_df,x='Cuisine',y='Reviews',ax=ax)
# Out:
# <AxesSubplot:xlabel='Cuisine', ylabel='Reviews'>

# %%
f,ax = plt.subplots(figsize=(15,25))
plt.xticks(rotation=90)
sns.scatterplot(data=restaurant_bus_df,y='Cuisine',x='Zip-Code',palette=['red','red','red','red','blue','blue','green','green','green'],hue='Ratings')
# Out:
# <AxesSubplot:xlabel='Zip-Code', ylabel='Cuisine'>

# %% [markdown]
# The above plot shows relationship between cuisine,Zip codes and ratings. As indicated earlier that most of the restaurants have
# average ratings, few more have very good ratings and very few have poor ratings. The important point to be noted here is that
# "food delivery services" have very poor ratings, this could be an indicator of bad road conditions or heavy traffic.

# %% [markdown]
# Supervised Learning starts

# %%
#merging of restaurant and income data

# %%
income_data.IncomeperReturn=income_data.IncomeperReturn.apply(lambda x:x.replace('$','').replace(',','.').strip()).astype(float)
income_data.SalaryperReturn=income_data.SalaryperReturn.apply(lambda x:x.replace('$','').replace(',','.').strip()).astype(float)
income_data.TaxPaidperReturn=income_data.TaxPaidperReturn.apply(lambda x:x.replace('$','').replace(',','.').strip()).astype(float)
income_data.drop(columns=['Unnamed: 8','Unnamed: 9','State'],inplace=True)
income_data.City = income_data.City.fillna('Blank')
income_data.drop(index=income_data[income_data.ZipCode=='GEORGIA'].index[0],inplace=True)

# %%
restaurant_income_data=restaurant_bus_df.merge(right=income_data,how='inner',left_on='Zip-Code',right_on='ZipCode')
zip_codes = restaurant_income_data['Zip-Code'].unique()
cuisines = restaurant_income_data.Cuisine.unique()
restaurant_income_data.drop(columns=['ZipCode','City'],inplace=True)

# %% [markdown]
# Each restaurant is given a score. This score will indicate how good a restaurant is doing in a ceratin area.
# The score value is raning between 0 and 1. A score of 1 is considered best whereas a score of 0 is considered bad. Restaurants
# whose score is near to 1 is doing better than those whose score is near to 0.

# %% [markdown]
# Calculation of score of a restaurants is based on the below formula.
#
# score = norm(((rating-mean rating)/max rating)*(number of reveiws))

# %%
mean_rating=restaurant_income_data.Ratings.unique().mean()
max_rating=restaurant_income_data.Ratings.unique().max()
scores=[int(max(((restaurant_income_data.iloc[i].Ratings-mean_rating)/max_rating)*restaurant_income_data.iloc[i].Reviews,0)) for i in restaurant_income_data.index]
#restaurant_income_data.insert(loc=len(restaurant_income_data.columns),value=scores,column='score')
restaurant_income_data.drop(columns=['Ratings','Reviews'],inplace=True)

# %%
encoder=OrdinalEncoder()
scaler = MinMaxScaler()
restaurant_income_data[['Cuisine','Zip-Code']]=encoder.fit_transform(restaurant_income_data[['Cuisine','Zip-Code']])
restaurant_income_data[restaurant_income_data.columns]=scaler.fit_transform(restaurant_income_data)

# %% [markdown]
# Relationship between features and the score through "kernel density estimates"

# %%
sns.pairplot(restaurant_income_data,kind='kde')

# %% [markdown]
# Predicting score of a restaurant using "Deep neural Network"

# %%
#data split between train and test
scaler_score = MinMaxScaler()
y_data = scaler_score.fit_transform(np.expand_dims(scores,axis=-1))
x_data = restaurant_income_data.values
x_train,x_test,y_train,y_test = train_test_split(x_data,y_data,train_size=0.8,shuffle=True)

# %%
#deep neural network creation
m = Sequential()
m.add(Dense(100,activation='relu'))
m.add(Dropout(0.2))
m.add(Dense(50,activation='relu'))
m.add(Dropout(0.1))
m.add(Dense(10,activation='relu'))
m.add(Dense(1,activation='relu'))

m.compile(optimizer=Adam(learning_rate=0.0001),loss='mse',metrics=[RootMeanSquaredError()])

# %%
#training
chkpt = ModelCheckpoint(filepath='weights.{epoch:02d}-{val_root_mean_squared_error:.4f}.hdf5',monitor='val_root_mean_squared_error',mode='min',save_best_only=True)
erly_stoping = EarlyStopping(monitor='val_root_mean_squared_error',mode='min',patience=3,restore_best_weights=True) 
m.fit(x_train,y_train,batch_size=32,epochs=20,validation_data=(x_test,y_test),callbacks=[chkpt,erly_stoping])
# Out:
# Epoch 1/20
# 11/11 [==============================] - 5s 14ms/step - loss: 0.0459 - root_mean_squared_error: 0.2142 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 2/20
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0362 - root_mean_squared_error: 0.1902 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 3/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0308 - root_mean_squared_error: 0.1755 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 4/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 5/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 6/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 7/20
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 8/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 9/20
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 10/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 11/20
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0587

# %% [markdown]
# **model evaluation below

# %%
m = load_model('weights.08-0.0575.hdf5')

# %%
zipcode = input('Enter a Zip code')
price_range = min(3,max(int(input('Enter a price range')),0))
# Out:
# Enter a Zip code30214
# Enter a price range4

# %%
if zipcode not in zip_codes:
    print('Error!! zip code not in dataset')
else:
    Number_of_returns = income_data[income_data.ZipCode==zipcode].NumberReturns.iloc[0]
    Gross_income = income_data[income_data.ZipCode==zipcode]['AdjustedGross Income'].iloc[0]
    income_per_ret = income_data[income_data.ZipCode==zipcode].IncomeperReturn.iloc[0]
    sal_per_ret = income_data[income_data.ZipCode==zipcode].SalaryperReturn.iloc[0]
    tax_per_ret = income_data[income_data.ZipCode==zipcode].TaxPaidperReturn.iloc[0]
    evaluation_df = pd.DataFrame(data={'Cuisine':cuisines,'Zip-Code':[zipcode]*unique_cuisines,'Price_Rng_enc':[price_range]*unique_cuisines,'NumberReturns':[Number_of_returns]*unique_cuisines,'AdjustedGross Income':[Gross_income]*unique_cuisines,'IncomeperReturn':[income_per_ret]*unique_cuisines,'SalaryperReturn':[sal_per_ret]*unique_cuisines,'TaxPaidperReturn':[tax_per_ret]*unique_cuisines})
    evaluation_df[['Cuisine','Zip-Code']]=encoder.transform(evaluation_df[['Cuisine','Zip-Code']])
    evaluation_df[evaluation_df.columns]=scaler.transform(evaluation_df)
    predicted_score = m.predict(evaluation_df)
    top_5_pred_idx = np.argpartition(np.squeeze(predicted_score), -5)[-5::]
    top_5_predictions = cuisines[top_5_pred_idx]

# %%
top_5_predictions
# Out:
# array(['Vegan', 'Vegetarian', 'Venues & Event Spaces', 'Venezuelan',
#        'Vietnamese'], dtype=object)

# %%
restaurant_bus_df[restaurant_bus_df['Zip-Code']==zipcode].sort_values(by=['Reviews','Ratings'],ascending=False)
# Out:
#            Cuisine  Ratings  Reviews Zip-Code  Price_Rng_enc
# 273  Chicken Wings      4.0      225    30214              1

# %%
top_5_pred_idx = np.argpartition(np.squeeze(predicted_score), -5)[-5::]

# %%
top_5_predictions = cuisines[top_5_pred_idx]

# %%
zip_codes
# Out:
# array(['30342', '30307', '30308', '30309', '30324', '30303', '30305',
#        '30306', '30084', '30361', '30326', '30519', '30328', '30345',
#        '30033', '30030', '30319', '30320', '30078', '30338', '30360',
#        '30214', '30022', '30002', '30067', '30075', '30013', '30062',
#        '30096', '30350', '30144', '30346', '30097', '30301', '30024'],
#       dtype=object)
